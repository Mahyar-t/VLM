# %% [markdown]
# # NiluLab 🪷 - Google Colab Deployment
#
# This notebook allows you to run NiluLab for free using a T4 GPU and ngrok.
#
# ### 1. Requirements
# - **Runtime Type**: T4 GPU (Runtime > Change runtime type > T4 GPU)
# - **ngrok Token**: Get one for free at [dashboard.ngrok.com](https://dashboard.ngrok.com/get-started/your-authtoken)

# %%
# @title 🚀 Start NiluLab
import os
NGROK_TOKEN = "" # @param {type:"string"}

# !rm -rf VLM
# !git clone -b feat/colab_deployment https://github.com/Mahyar-t/VLM.git
# %cd VLM
# !python3 scripts/colab_setup.py --token {NGROK_TOKEN}
